# %% [markdown]
# ### For loops
#
# Whenever you want to apply any transformation to all elements in a list, you iterate through them with a `for` loop.

# %%
names_list = ["Justine", "Amabel", "Karl"]

for name in names_list:
    print("Hello " + name + "!")
# Out:
# Hello Justine!
# Hello Amabel!
# Hello Karl!

# %% [markdown]
# Here, the word `name` could really be anything. It is just a placeholder that takes the value of each element in the for loop in every sucessive iteration, until the loop reaches the end of the list. Using a diferent name does not change the result:

# %%
for dinosaur in names_list:
    print("Hello " + dinosaur + "!")
# Out:
# Hello Justine!
# Hello Amabel!
# Hello Karl!

# %% [markdown]
# If we wanted to store the resulting transformations of our loop into a new list, we would define an empty list first, and then `append()` all the elements as we iterate through the loop:

# %%
greetings = []

for name in names_list:
    greetings.append("Hello " + name + "!")

# %%
greetings
# Out:
# ['Hello Justine!', 'Hello Amabel!', 'Hello Karl!']

# %% [markdown]
# **Exercise 1**. Create a List named `lower_names` with all the names of the students in your batch. Include name and surname, all in lowercase (like `john doe`).

# %%
lower_names = ["friederich simon", "alexander friedrich", "grete lehmann",
               "irmgard bergmann", "ruben pfeiffer", "therese krämer",
               "adolf thomas", "stefan schulze", "phiplipp hartmann",
               "bastian roth"]

# %% [markdown]
# **Exercise 2** Create a new list `capital_names`  with both the names and surnames capitalized (like `John Doe`), by iterating through the first list with a `for` loop.
#
# *Hint: use the method .title() to capitalize all the words in a string*

# %%
capital_names = []

for name in lower_names:
  capital_names.append(name.title())

print(capital_names)
# Out:
# ['Friederich Simon', 'Alexander Friedrich', 'Grete Lehmann', 'Irmgard Bergmann', 'Ruben Pfeiffer', 'Therese Krämer', 'Adolf Thomas', 'Stefan Schulze', 'Phiplipp Hartmann', 'Bastian Roth']

# %% [markdown]
# ### Conditions with `if`
#
# Whenever you want to do something only if a condition is met, you will need an `if` statement. Let's say we want to greet people only if their name starts with "A". We will add a few more names to our list:

# %%
names_list = ["Justine", "Amabel", "Karl", "Anna", "Lina", "Sergei", "Magnus", "Aurora"]

# %% [markdown]
# We can check one by one whether they start with "A" by selecting them from the list by their position using `[]`, and using the string method you already learned `starts_with()`:

# %%
# Justine
print(names_list[0].startswith("A"))

# Amabel
print(names_list[1].startswith("A"))
# Out:
# False
# True

# %% [markdown]
# These booleans, `True` or `False`, are exactly what `if` statements need. Whenever a condition is true, the code below the `if` statement runs; if the condition is false, the code is skipped and nothing happens:

# %%
condition = True

if condition:
    print("yay")
# Out:
# yay

# %%
condition = False

if condition:
    print("yay")

# %% [markdown]
# So we can now tie everything together:
#
# - A for loop that iterates through the names.
#
# - An `if` statment that checks whether the name starts with "A".
#
# - A greeting.

# %%
for name in names_list:
    if name.startswith("A"):
        print("Hello " + name + "!")
# Out:
# Hello Amabel!
# Hello Anna!
# Hello Aurora!

# %% [markdown]
# An `else` statement can be added if you want to do something with the elements that did not meet the condition.
#
# After the `if` and the `else` statements, you can continue coding normally —and the code will run independently of any conditions. Here, we print some text and a line break:

# %%
i=1
for name in names_list:
    if name.startswith("A"):
        print("Hello " + name + "!")
    else:
        print("Bye " + name + "!")
    if(i != len(names_list)):
        print
    i+=1
# Out:
# Bye Justine!
# Hello Amabel!
# Bye Karl!
# Hello Anna!
# Bye Lina!
# Bye Sergei!
# Bye Magnus!
# Hello Aurora!

# %% [markdown]
# Let's add a text that gets printed after each iteration of the loop, so it is clearer what's going on...

# %%
for name in names_list:
    if name.startswith("A"):
        print("Hello " + name + "!")
    else:
        print("Bye " + name + "!")
    print("next iteration incoming... \n")
# Out:
# Bye Justine!
# next iteration incoming...
#
# Hello Amabel!
# next iteration incoming...
#
# Bye Karl!
# next iteration incoming...
#
# Hello Anna!
# next iteration incoming...
#
# Bye Lina!
# next iteration incoming...
#
# Bye Sergei!
# next iteration incoming...
#
# Bye Magnus!
# next iteration incoming...
#
# Hello Aurora!
# next iteration incoming...

# %% [markdown]
# **Exercise 3** In the previous code, the "next iteration incoming..." text gets printed also for the last iteration, which might be confusing for whoever is reading the output of this code. Tweak the code so that this text only gets printed if we are not in the last element of our list.
#
# **Tip**: it is totally normal if you don't know how to approach this exercise right away. You might need to use something we have not seeen in this lesson or the previous ones. Google is your friend! If you are stuck for a long time (above 30 min), and have already tried many things, it's time to ask for help to your instructor.

# %%
# code here
for idx, name in enumerate(names_list, start=1):
    if name.startswith("A"):
        print("Hello " + name + "!")
    else:
        print("Bye " + name + "!")
    if idx < len(names_list):
      print("next iteration incoming... \n")
# Out:
# Bye Justine!
# next iteration incoming...
#
# Hello Amabel!
# next iteration incoming...
#
# Bye Karl!
# next iteration incoming...
#
# Hello Anna!
# next iteration incoming...
#
# Bye Lina!
# next iteration incoming...
#
# Bye Sergei!
# next iteration incoming...
#
# Bye Magnus!
# next iteration incoming...
#
# Hello Aurora!

# %% [markdown]
# **Exercise 4:**
#
#
# **4.1.** Take 50 samples (with replacement), each one of size 10, from `numbers_ser` series.

# %%
import pandas as pd

numbers = [1, 51, 59, 2, 95, 25, 28, 67, 14, 63, 84, 33, 56, 31, 54, 97, 77, 
            98, 46, 84, 6, 66, 86, 77, 69, 19, 77, 7, 76, 19, 59, 77, 28, 34, 
            94, 4, 45, 95, 41, 66, 5, 38, 35, 57, 84, 38, 94, 65, 45, 80, 83, 
            22, 12, 100, 52, 55, 31, 69, 29, 67, 4, 39, 87, 49, 81, 82, 96, 4, 
            85, 62, 90, 72, 70, 26, 29, 63, 48, 94, 58, 9, 49, 79, 33, 63, 41, 
            13, 90, 37, 31, 3, 11, 54, 56, 72, 91, 97, 2, 83, 82, 6]

numbers_ser = pd.Series(numbers)

# %%
# 4.1. solution

samples = []

for i in range(50): #also can use range(1,51)
  samples.append(numbers_ser.sample(10, replace=True).to_list())

samples
# Out:
# [[35, 54, 41, 55, 4, 82, 95, 82, 56, 77],
#  [98, 57, 77, 91, 49, 31, 31, 67, 28, 70],
#  [59, 63, 79, 77, 19, 98, 86, 67, 94, 72],
#  [3, 96, 90, 41, 94, 55, 38, 1, 56, 19],
#  [80, 79, 4, 54, 26, 37, 4, 63, 41, 66],
#  [69, 97, 1, 84, 41, 65, 45, 56, 83, 33],
#  [57, 35, 67, 77, 63, 95, 45, 13, 28, 83],
#  [31, 87, 6, 56, 39, 31, 59, 46, 84, 12],
#  [90, 85, 95, 49, 58, 35, 4, 66, 19, 13],
#  [31, 69, 94, 80, 48, 63, 80, 39, 85, 63],
#  [46, 33, 77, 45, 69, 84, 26, 19, 54, 4],
#  [49, 67, 81, 82, 1, 39, 84, 6, 83, 13],
#  [57, 11, 34, 96, 85, 28, 94, 19, 90, 63],
#  [97, 67, 67, 57, 63, 46, 29, 56, 31, 37],
#  [14, 85, 94, 41, 31, 4, 39, 26, 82, 85],
#  [72, 33, 97, 19, 69, 100, 59, 2, 34, 46],
#  [66, 65, 54, 33, 82, 84, 26, 80, 41, 33],
#  [25, 58, 13, 33, 51, 34, 84, 57, 87, 49],
#  [90, 97, 82, 26, 69, 63, 46, 41, 14, 84],
#  [84, 9, 33, 29, 69, 31, 13, 3, 49, 66],
#  [82, 13, 66, 76, 13, 56, 90, 62, 25, 4],
#  [86, 91, 49, 31, 94, 49, 56, 84, 12, 4],
#  [72, 85, 3, 56, 31, 63, 45, 91, 49, 63],
#  [84, 76, 31, 84, 83, 77, 82, 94, 100, 95],
#  [45, 82, 72, 97, 11, 49, 65, 4, 51, 86],
#  [95, 2, 33, 91, 33, 90, 14, 28, 56, 65],
#  [33, 14, 26, 77, 86, 77, 2, 72, 56, 3],
#  [77, 6, 77, 4, 13, 26, 31, 94, 70, 77],
#  [19, 56, 52, 77, 82, 12, 90, 86, 91, 5],
#  [22, 96, 94, 82, 6, 62, 69, 65, 77, 97],
#  [25, 83, 85, 39, 77, 85, 84, 59, 87, 26],
#  [66, 51, 49, 35, 6, 95, 9, 13, 66, 58],
#  [39, 86, 33, 38, 91, 83, 56, 83, 57, 51],
#  [72, 79, 97, 59, 72, 95, 63, 29, 63, 82],
#  [41, 4, 31, 96, 90, 83, 3, 52, 34, 26],
#  [3, 12, 12, 70, 45, 26, 45, 29, 96, 84],
#  [91, 59, 82, 52, 19, 69, 58, 4, 94, 63],
#  [58, 38, 90, 90, 63, 34, 45, 56, 54, 77],
#  [77, 25, 90, 59, 70, 96, 28, 26, 31, 7],
#  [2, 63, 63, 83, 52, 69, 94, 25, 19, 90],
#  [28, 63, 77, 38, 33, 69, 5, 70, 69, 94],
#  [9, 98, 94, 56, 6, 54, 77, 77, 72, 77],
#  [91, 80, 3, 72, 28, 28, 84, 26, 52, 70],
#  [91, 77, 77, 5, 82, 13, 82, 85, 97, 65],
#  [31, 87, 56, 63, 14, 19, 83, 33, 19, 77],
#  [58, 58, 52, 63, 90, 41, 97, 100, 49, 82],
#  [81, 57, 69, 77, 72, 45, 94, 38, 38, 33],
#  [28, 82, 54, 98, 98, 59, 87, 97, 66, 2],
#  [94, 97, 6, 6, 34, 91, 66, 83, 19, 63],
#  [72, 59, 7, 94, 29, 67, 100, 7, 48, 26]]

# %% [markdown]
# **4.2.** Create a list with the mean of all the samples you collected:

# %%
# 4.2. solution:

sample_means = []

for s in samples:
  sample_means.append(pd.Series(s).mean())

print(sample_means)
# Out:
# [58.1, 59.9, 71.4, 49.3, 45.4, 57.4, 56.3, 45.1, 51.4, 65.2, 45.7, 50.5, 57.7, 55.0, 50.1, 53.1, 56.4, 49.1, 61.2, 38.6, 48.7, 55.6, 55.8, 80.6, 56.2, 50.7, 44.6, 47.5, 57.0, 67.0, 65.0, 44.8, 61.7, 71.1, 46.0, 42.2, 59.1, 60.5, 50.9, 56.0, 54.6, 62.0, 53.4, 67.4, 48.2, 69.0, 60.4, 67.1, 55.9, 50.9]

# %% [markdown]
# ### Bonus exercises
#
# **Exercise 5.** Implement the for loop that greets people for the `characters` list you used in the previous exercises. For now, do not include any condition —just say hello to every character. What do you need to do to iterate through lists inside a list?

# %%
characters = [["Harry", "Hermoine", "Ron"], 
              ["Daenerys Targaryen", "Jon Snow", "Tyrion Lannister", 
               "Cercei Lannister", "Arya Stark", "Sansa Stark"],
              ["Aragorn", "Gandalf", "Frodo", "Legolas", "Gollum", "Gimli"],
              ["Walter White", "Jesse Pinkman", "Gus Fring"]
             ]

# %%
for l in characters:
    for name in l:
        print(f"Hello {name}!")
# Out:
# Hello Harry!
# Hello Hermoine!
# Hello Ron!
# Hello Daenerys Targaryen!
# Hello Jon Snow!
# Hello Tyrion Lannister!
# Hello Cercei Lannister!
# Hello Arya Stark!
# Hello Sansa Stark!
# Hello Aragorn!
# Hello Gandalf!
# Hello Frodo!
# Hello Legolas!
# Hello Gollum!
# Hello Gimli!
# Hello Walter White!
# Hello Jesse Pinkman!
# Hello Gus Fring!

# %% [markdown]
# Alternate method 1

# %%
for i in characters:
  for n in i:

    print('hello ' + n)
# Out:
# hello Harry
# hello Hermoine
# hello Ron
# hello Daenerys Targaryen
# hello Jon Snow
# hello Tyrion Lannister
# hello Cercei Lannister
# hello Arya Stark
# hello Sansa Stark
# hello Aragorn
# hello Gandalf
# hello Frodo
# hello Legolas
# hello Gollum
# hello Gimli
# hello Walter White
# hello Jesse Pinkman
# hello Gus Fring

# %% [markdown]
# Alternate method 2

# %%
for i in characters:
  for name in i:
    print("Hello ", name)
# Out:
# Hello  Harry
# Hello  Hermoine
# Hello  Ron
# Hello  Daenerys Targaryen
# Hello  Jon Snow
# Hello  Tyrion Lannister
# Hello  Cercei Lannister
# Hello  Arya Stark
# Hello  Sansa Stark
# Hello  Aragorn
# Hello  Gandalf
# Hello  Frodo
# Hello  Legolas
# Hello  Gollum
# Hello  Gimli
# Hello  Walter White
# Hello  Jesse Pinkman
# Hello  Gus Fring

# %% [markdown]
# **Exercise 6.** Tweak the code of the previous exercise to greet characters based on these conditions:
#
# - If their name is composed of two words (Name Surname), the greeting should be "Hello Name, from the house of Surname".
#
# - If their first name is shorter than 6 characters, the greeting should replicate the last letter of the name as many times as needed until it reaches 6 characters.

# %%
for l in characters:
    for name in l:
        split_name = name.split(' ')
        if len(split_name[0]) < 6:
            split_name[0]=split_name[0].ljust(6, split_name[0][-1])
        
        if len(split_name) == 1:
            print(f"Hello {split_name[0]}!")
        else:
            print(f"Hello {split_name[0]}, from the house of {split_name[1]}")
# Out:
# Hello Harryy!
# Hello Hermoine!
# Hello Ronnnn!
# Hello Daenerys, from the house of Targaryen
# Hello Jonnnn, from the house of Snow
# Hello Tyrion, from the house of Lannister
# Hello Cercei, from the house of Lannister
# Hello Aryaaa, from the house of Stark
# Hello Sansaa, from the house of Stark
# Hello Aragorn!
# Hello Gandalf!
# Hello Frodoo!
# Hello Legolas!
# Hello Gollum!
# Hello Gimlii!
# Hello Walter, from the house of White
# Hello Jessee, from the house of Pinkman
# Hello Gussss, from the house of Fring

# %% [markdown]
# Alternative 1

# %%
for ls in characters:
  for name in ls:
    name_new = name.split(' ')
    if len(name_new[0])<6:
      name_new[0] += 6*name_new[0][-1]
      name_new[0] = name_new[0][:6]
    if len(name_new)>1:
      print('Hello ' + name_new[0] + ', from the house of ' + name_new[1] + '!')
    else:
      print('Hello ' + name_new[0] + '!')
# Out:
# Hello Harryy!
# Hello Hermoine!
# Hello Ronnnn!
# Hello Daenerys, from the house of Targaryen!
# Hello Jonnnn, from the house of Snow!
# Hello Tyrion, from the house of Lannister!
# Hello Cercei, from the house of Lannister!
# Hello Aryaaa, from the house of Stark!
# Hello Sansaa, from the house of Stark!
# Hello Aragorn!
# Hello Gandalf!
# Hello Frodoo!
# Hello Legolas!
# Hello Gollum!
# Hello Gimlii!
# Hello Walter, from the house of White!
# Hello Jessee, from the house of Pinkman!
# Hello Gussss, from the house of Fring!

# %% [markdown]
# Alternative 2

# %%
for i in characters:
  for n in i:
    if len(n.split())> 1:
      print( "Hello "+ n.split()[0]+", from the house of "+n.split()[1])

    elif len(n.split())== 1:
      print('Hello ' +n.ljust(6,n[-1]))

    else:
      print('Hello '  + n)
# Out:
# Hello Harryy
# Hello Hermoine
# Hello Ronnnn
# Hello Daenerys, from the house of Targaryen
# Hello Jon, from the house of Snow
# Hello Tyrion, from the house of Lannister
# Hello Cercei, from the house of Lannister
# Hello Arya, from the house of Stark
# Hello Sansa, from the house of Stark
# Hello Aragorn
# Hello Gandalf
# Hello Frodoo
# Hello Legolas
# Hello Gollum
# Hello Gimlii
# Hello Walter, from the house of White
# Hello Jesse, from the house of Pinkman
# Hello Gus, from the house of Fring
